# %% [markdown]
# ## Pandas tips and tricks

# %%
import pandas as pd

# %%
# load dataset to work with
import seaborn as sns

# titanic dataset ko load krein
kashti = sns.load_dataset("titanic")

# %%
kashti.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
kashti.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
# what every column means in every dataset ?
# how many datasets are there in sns.dataset() ?

# %%
import seaborn as sns
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
# total number of datasets in sns
len(sns.get_dataset_names())
# Out:
# 22

# %%
kashti.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# doswnload phool datasset
phool = sns.load_dataset("iris")
phool.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
phool.sample(100)   # phool ke table me se random 100 rows dikhayein
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 35            5.0          3.2           1.2          0.2      setosa
# 126           6.2          2.8           4.8          1.8   virginica
# 66            5.6          3.0           4.5          1.5  versicolor
# 5             5.4          3.9           1.7          0.4      setosa
# 146           6.3          2.5           5.0          1.9   virginica
# ..            ...          ...           ...          ...         ...
# 29            4.7          3.2           1.6          0.2      setosa
# 95            5.7          3.0           4.2          1.2  versicolor
# 3             4.6          3.1           1.5          0.2      setosa
# 48            5.3          3.7           1.5          0.2      setosa
# 37            4.9          3.6           1.4          0.1      setosa
#
# [100 rows x 5 columns]

# %%
phool.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
kashti.to_excel("kashti_data.xlsx", index=False)

# %%
phool.to_excel("phool_data.xlsx", index=False)

# %%
phool.to_excel('../day_01/iris_data.xlsx', index=False)

# %%
# importing data from other folder
df = pd.read_excel('../day_01/iris_data.xlsx')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
df['petal_length']   # one dimentional
# df['petal_length','petal_width']  # one dimentional can't print two columns like this (this gives error)
df[['petal_length','petal_width']]   # two dimentional print krne ke liye double square brackets lagate hain
# Out:
#      petal_length  petal_width
# 0             1.4          0.2
# 1             1.4          0.2
# 2             1.3          0.2
# 3             1.5          0.2
# 4             1.4          0.2
# ..            ...          ...
# 145           5.2          2.3
# 146           5.0          1.9
# 147           5.2          2.0
# 148           5.4          2.3
# 149           5.1          1.8
#
# [150 rows x 2 columns]

# %%
# unique values in a column
df.petal_length.unique()
# Out:
# array([1.4, 1.3, 1.5, 1.7, 1.6, 1.1, 1.2, 1. , 1.9, 4.7, 4.5, 4.9, 4. ,
#        4.6, 3.3, 3.9, 3.5, 4.2, 3.6, 4.4, 4.1, 4.8, 4.3, 5. , 3.8, 3.7,
#        5.1, 3. , 6. , 5.9, 5.6, 5.8, 6.6, 6.3, 6.1, 5.3, 5.5, 6.7, 6.9,
#        5.7, 6.4, 5.4, 5.2])

# %%
df.species.unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df.groupby(['petal_length']).describe().T
# Out:
# petal_length        1.0  1.1       1.2       1.3        1.4        1.5  \
# sepal_length count  1.0  1.0  2.000000  7.000000  13.000000  13.000000
#              mean   4.6  4.3  5.400000  4.842857   4.915385   5.146154
#              std    NaN  NaN  0.565685  0.464963   0.288231   0.275727
#              min    4.6  4.3  5.000000  4.400000   4.400000   4.600000
#              25%    4.6  4.3  5.200000  4.450000   4.800000   5.000000
#              50%    4.6  4.3  5.400000  4.700000   4.900000   5.100000
#              75%    4.6  4.3  5.600000  5.200000   5.100000   5.300000
#              max    4.6  4.3  5.800000  5.500000   5.500000   5.700000
# sepal_width  count  1.0  1.0  2.000000  7.000000  13.000000  13.000000
#              mean   3.6  3.0  3.600000  3.228571   3.353846   3.569231
#              std    NaN  NaN  0.565685  0.502375   0.352646   0.390266
#              min    3.6  3.0  3.200000  2.300000   2.900000   3.100000
# ...

# %%
kashti.groupby(['survived','sex']).describe()
# Out:
#                 pclass                                                 age  \
#                  count      mean       std  min  25%  50%  75%  max  count
# survived sex
# 0        female   81.0  2.851852  0.450309  1.0  3.0  3.0  3.0  3.0   64.0
#          male    468.0  2.476496  0.761411  1.0  2.0  3.0  3.0  3.0  360.0
# 1        female  233.0  1.918455  0.834211  1.0  1.0  2.0  3.0  3.0  197.0
#          male    109.0  2.018349  0.922774  1.0  1.0  2.0  3.0  3.0   93.0
#
#                             ... parch        fare                        \
#                       mean  ...   75%  max  count       mean        std
# survived sex                ...
# 0        female  25.046875  ...   2.0  6.0   81.0  23.024385  24.821287
#          male    31.618056  ...   0.0  5.0  468.0  21.960993  32.409799
# 1        female  28.847716  ...   1.0  5.0  233.0  51.938573  64.102256
#          male    27.276022  ...   1.0  2.0  109.0  40.821484  71.355967
#
#
# ...

# %%
kashti.groupby(['survived','sex'])["survived"].count()
# Out:
# survived  sex
# 0         female     81
#           male      468
# 1         female    233
#           male      109
# Name: survived, dtype: int64

# %%
kashti.groupby(['survived','sex','who'])['who'].count()
# Out:
# survived  sex     who
# 0         female  child     15
#                   woman     66
#           male    child     19
#                   man      449
# 1         female  child     28
#                   woman    205
#           male    child     21
#                   man       88
# Name: who, dtype: int64

# %%
import seaborn as sns
sns.countplot(x='survived', data=kashti)
# Out:
# <Axes: xlabel='survived', ylabel='count'>

# %%
kashti.survived.value_counts()
# Out:
# survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
sns.countplot(x='survived',hue = 'sex', data=kashti)
# Out:
# <Axes: xlabel='survived', ylabel='count'>
