# %% [markdown]
#  # Code ko seprate karne ke lia ipynp file banti ha

# %%
# code 1
print("Umair")
# Out:
# Umair

# %% [markdown]
# *Simple print string statement*

# %%
# code 2
name = input("What is your name ")

# %%
# code 3
print("welcome",name)
# Out:
# welcome umair

# %%
samosa = ("Aloo",'Pyaz',"Sabz_mirch",'anar_dana',"meida",'namak')

# %%
# print(samosa)
samosa
# Out:
# ('Aloo', 'Pyaz', 'Sabz_mirch', 'anar_dana', 'meida', 'namak')

# %% [markdown]
# # subject of this python script : \
# # Auther by : Umair Asghar \
# # WHere to contact : github link & Email (gmail) google collab \
# [lecture-5](https://www.youtube.com/live/V5Pk5qvRo7A?si=emx-EzVdOzfrvbjh)
